# %% [markdown]
# <a href="https://colab.research.google.com/github/Ingy10/Ingy10/blob/main/Quantitative_Strategy_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Here we are importing a data set that includes performance data for 56 famous investing strategies from 1998 to 2024.  These strategies have been quantified and tracked by the American Association of Individual Investors (AAII.com).
#
# Previously active investing would incur costs but in the era of $0 trading commissions this is no longer true.  Therefore I hope to determine what opportunities exist for retail investors to implement investing strategies to gain alpha in today's stock market.

# %%
import pandas as pd;
df = pd.read_csv('Quantitative_strategies_performance_table_Capstone1.csv');

# %% [markdown]
# I have set the date as the index and printed a cursory look at the data.

# %%
df = df.rename(columns={'date_': 'Date'});
df = df.set_index('Date');
print(df.head());
# Out:
#             ADR Screen  All Stocks  Buffett: Hagstrom Screen  \
# Date
# 1998-01-31        2.99        6.22                      1.48
# 1998-02-28        5.54        6.60                     10.70
# 1998-03-31        4.23        7.69                     -0.13
# 1998-04-30       -0.97        4.09                      3.29
# 1998-05-31       -2.24       -2.49                     -4.37
#
#             Buffettology: EPS Growth  Buffettology: Sustainable Growth Screen  \
# Date
# 1998-01-31                      0.81                                     2.16
# 1998-02-28                      6.22                                     7.81
# 1998-03-31                     -1.01                                    -0.80
# 1998-04-30                      1.50                                     2.16
# 1998-05-31                     -5.41                                    -6.55
#
#             Cash Rich Firms Screen  Dividend (High Relative Yield) Screen  \
# Date
# 1998-01-31                    2.97                                  -0.95
# 1998-02-28                    5.56                                   8.59
# 1998-03-31                    6.39                                   4.13
# 1998-04-30                   -2.48                                   1.52
# 1998-05-31                   -5.19                                  -5.69
#
#             Dogs of the Dow Screen  Dogs of the Dow: Low Priced 5 Screen  \
# Date
# 1998-01-31                   -1.74                                 -2.11
# 1998-02-28                    6.81                                  8.32
# 1998-03-31                    3.67                                  4.23
# 1998-04-30                    1.84                                  1.30
# 1998-05-31                   -1.56                                 -0.06
#
#             Dreman Screen  ...  Rule #1 Investing Screen  Schloss Screen  \
# Date                       ...
# 1998-01-31          -2.12  ...                      4.25           -2.11
# 1998-02-28           5.74  ...                     11.72            3.43
# 1998-03-31           6.26  ...                     -0.61           -0.46
# 1998-04-30          -1.12  ...                      2.02           -0.58
# 1998-05-31          -1.22  ...                     -8.21            5.44
#
#             Stock Market Winners Screen  T. Rowe Price Screen  \
# Date
# 1998-01-31                        -2.88                  0.91
# 1998-02-28                         7.15                 12.52
# 1998-03-31                         5.77                  1.44
# 1998-04-30                        -1.20                 -0.31
# 1998-05-31                         1.08                 -5.45
#
#             Templeton Screen  Value on the Move--PEG With Est Growth Screen  \
# Date
# 1998-01-31              2.75                                           0.79
# 1998-02-28              9.62                                           7.78
# 1998-03-31              4.08                                           8.14
# 1998-04-30              5.49                                           2.26
# 1998-05-31             -3.48                                          -1.39
#
#             Value on the Move--PEG With Hist Growth Screen  \
# Date
# 1998-01-31                                           -0.52
# 1998-02-28                                            5.52
# 1998-03-31                                            5.36
# 1998-04-30                                            1.10
# 1998-05-31                                           -2.67
#
#             Wanger (Revised) Screen  Weiss Blue Chip Div Yield Screen  \
# Date
# 1998-01-31                    -1.43                             -2.79
# 1998-02-28                     7.84                             10.76
# 1998-03-31                     4.07                             -0.08
# 1998-04-30                    -1.76                             -1.06
# 1998-05-31                    -5.94                             -7.00
#
#             Zweig Screen
# Date
# 1998-01-31         -4.18
# 1998-02-28         16.67
# 1998-03-31         13.38
# 1998-04-30         13.57
# 1998-05-31          4.09
#
# [5 rows x 56 columns]

# %% [markdown]
# Here I am checking data types.  All are floats and I can see there are some null values present.

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 321 entries, 1998-01-31 to 2024-09-30
# Data columns (total 56 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   ADR Screen                                       321 non-null    float64
#  1   All Stocks                                       250 non-null    float64
#  2   Buffett: Hagstrom Screen                         321 non-null    float64
#  3   Buffettology: EPS Growth                         321 non-null    float64
#  4   Buffettology: Sustainable Growth Screen          321 non-null    float64
#  5   Cash Rich Firms Screen                           321 non-null    float64
#  6   Dividend (High Relative Yield) Screen            321 non-null    float64
#  7   Dogs of the Dow Screen                           321 non-null    float64
#  8   Dogs of the Dow: Low Priced 5 Screen             321 non-null    float64
#  9   Dreman Screen                                    321 non-null    float64
#  10  Dreman With Est Revisions Screen                 321 non-null    float64
#  11  Driehaus Revised Screen                          309 non-null    float64
#  12  Driehaus Screen                                  309 non-null    float64
#  13  Dual Cash Flow Screen                            321 non-null    float64
#  14  Est Rev: Down 5% Screen                          321 non-null    float64
#  15  Est Rev: Lowest 30 Down                          321 non-null    float64
#  16  Est Rev: Top 30 Up                               321 non-null    float64
#  17  Est Rev: Up 5% Screen                            321 non-null    float64
#  18  Fisher (Philip) Screen                           321 non-null    float64
#  19  Fundamental Rule of Thumb Screen                 321 non-null    float64
#  20  Graham--Defensive Investor (Non-Utility) Screen  321 non-null    float64
#  21  Graham--Defensive Investor (Utility) Screen      321 non-null    float64
#  22  Graham--Enterprising Investor Revised            321 non-null    float64
#  23  Insider Net Purchases Screen                     309 non-null    float64
#  24  Kirkpatrick Bargain Screen                       309 non-null    float64
#  25  Kirkpatrick Growth Screen                        309 non-null    float64
#  26  Kirkpatrick Value Screen                         309 non-null    float64
#  27  Lakonishok Screen                                321 non-null    float64
#  28  Lynch Screen                                     321 non-null    float64
#  29  Magic Formula Screen                             321 non-null    float64
#  30  Muhlenkamp Screen                                321 non-null    float64
#  31  Neff Screen                                      321 non-null    float64
#  32  O'Neil's CAN SLIM No Float Screen                321 non-null    float64
#  33  O'Neil's CAN SLIM Revised 3rd Edition Screen     321 non-null    float64
#  34  O'Neil's CAN SLIM Screen                         321 non-null    float64
#  35  O'Shaughnessy: All Cap Screen                    321 non-null    float64
#  36  O'Shaughnessy: Growth Market Leaders Screen      321 non-null    float64
#  37  O'Shaughnessy: Growth Screen II                  321 non-null    float64
#  38  O'Shaughnessy: Small Cap Growth & Value Screen   321 non-null    float64
#  39  O'Shaughnessy: Tiny Titans Screen                321 non-null    float64
#  40  O'Shaughnessy: Value Screen                      321 non-null    float64
#  41  P/E Relative Screen                              321 non-null    float64
#  42  Piotroski: High F-Score Screen                   321 non-null    float64
#  43  Price-to-Free-Cash-Flow Screen                   321 non-null    float64
#  44  Price-to-Sales Screen                            321 non-null    float64
#  45  Return on Equity Screen                          321 non-null    float64
#  46  Rule #1 Investing Screen                         321 non-null    float64
#  47  Schloss Screen                                   321 non-null    float64
#  48  Stock Market Winners Screen                      321 non-null    float64
#  49  T. Rowe Price Screen                             321 non-null    float64
#  50  Templeton Screen                                 321 non-null    float64
#  51  Value on the Move--PEG With Est Growth Screen    321 non-null    float64
#  52  Value on the Move--PEG With Hist Growth Screen   321 non-null    float64
#  53  Wanger (Revised) Screen                          321 non-null    float64
#  54  Weiss Blue Chip Div Yield Screen                 321 non-null    float64
#  55  Zweig Screen                                     321 non-null    float64
# dtypes: float64(56)
# memory usage: 142.9+ KB

# %% [markdown]
# Now I will look to see how many null values exist in each screen.

# %%
print(df.isnull().sum());
# Out:
# ADR Screen                                          0
# All Stocks                                         71
# Buffett: Hagstrom Screen                            0
# Buffettology: EPS Growth                            0
# Buffettology: Sustainable Growth Screen             0
# Cash Rich Firms Screen                              0
# Dividend (High Relative Yield) Screen               0
# Dogs of the Dow Screen                              0
# Dogs of the Dow: Low Priced 5 Screen                0
# Dreman Screen                                       0
# Dreman With Est Revisions Screen                    0
# Driehaus Revised Screen                            12
# Driehaus Screen                                    12
# Dual Cash Flow Screen                               0
# Est Rev: Down 5% Screen                             0
# Est Rev: Lowest 30 Down                             0
# Est Rev: Top 30 Up                                  0
# Est Rev: Up 5% Screen                               0
# Fisher (Philip) Screen                              0
# Fundamental Rule of Thumb Screen                    0
# Graham--Defensive Investor (Non-Utility) Screen     0
# Graham--Defensive Investor (Utility) Screen         0
# Graham--Enterprising Investor Revised               0
# Insider Net Purchases Screen                       12
# Kirkpatrick Bargain Screen                         12
# Kirkpatrick Growth Screen                          12
# Kirkpatrick Value Screen                           12
# Lakonishok Screen                                   0
# Lynch Screen                                        0
# Magic Formula Screen                                0
# Muhlenkamp Screen                                   0
# Neff Screen                                         0
# O'Neil's CAN SLIM No Float Screen                   0
# O'Neil's CAN SLIM Revised 3rd Edition Screen        0
# O'Neil's CAN SLIM Screen                            0
# O'Shaughnessy: All Cap Screen                       0
# O'Shaughnessy: Growth Market Leaders Screen         0
# O'Shaughnessy: Growth Screen II                     0
# O'Shaughnessy: Small Cap Growth & Value Screen      0
# O'Shaughnessy: Tiny Titans Screen                   0
# O'Shaughnessy: Value Screen                         0
# P/E Relative Screen                                 0
# Piotroski: High F-Score Screen                      0
# Price-to-Free-Cash-Flow Screen                      0
# Price-to-Sales Screen                               0
# Return on Equity Screen                             0
# Rule #1 Investing Screen                            0
# Schloss Screen                                      0
# Stock Market Winners Screen                         0
# T. Rowe Price Screen                                0
# Templeton Screen                                    0
# Value on the Move--PEG With Est Growth Screen       0
# Value on the Move--PEG With Hist Growth Screen      0
# Wanger (Revised) Screen                             0
# Weiss Blue Chip Div Yield Screen                    0
# Zweig Screen                                        0
# dtype: int64

# %% [markdown]
# Given that the 'All Stocks' is not tracked for more recent dates and is an outlier in terms of missing data points I will drop it from this dataset.

# %%
df = df.drop(columns=['All Stocks']);

# %% [markdown]
# With this data set I know that certain screens do not have data from the earliest dates. AAII started tracking certain screens after the initial start of the data set in 1998.  These screens started being tracked a year or two later.  Therefore I will drop all rows from those earliest dates so I will have a complete data set.  This will be assigned as a data frame to the variable 'df_screens'.

# %%
df_screens = df.dropna();

# %% [markdown]
# Now I will describe the data to get key insights from both the screens and dates.  Because there are so many screens and dates I will simply print the average of these metrics for all dates and all screens to keep things clean.  Remove mean() from either expression below to see data for individual dates or screens.

# %%
print(df_screens.T.mean().describe().head());
print(df_screens.mean().describe().head());
# Out:
# count    309.000000
# mean       1.095655
# std        5.183251
# min      -23.299091
# 25%       -1.940727
# dtype: float64
# count    55.000000
# mean      1.095655
# std       0.422567
# min       0.122524
# 25%       0.784207
# dtype: float64

# %% [markdown]
# Set index 'Date' to datetime format.

# %%
df_screens.index = pd.to_datetime(df_screens.index);

# %% [markdown]
# To provide a benchmark to compare these strategies, I will take an average of the performance of all the screens and assign it to 'Average Performance'.

# %%
df_screens = df_screens.copy();
df_screens['Average Performance'] = df_screens.mean(axis=1);
print(df_screens['Average Performance']);
# Out:
# Date
# 1999-01-31    3.121273
# 1999-02-28   -4.845636
# 1999-03-31    0.074727
# 1999-04-30    7.922909
# 1999-05-31    2.706182
#                 ...
# 2024-05-31    4.738000
# 2024-06-28   -2.554182
# 2024-07-31    5.810000
# 2024-08-30   -0.252182
# 2024-09-30    2.732727
# Name: Average Performance, Length: 309, dtype: float64

# %% [markdown]
# As a second benchmark I will bring in data for the SP500.

# %%
df_sp500 = pd.read_csv('SP500 monthly performance 1998 - 2024 Capstone1.csv');
df_sp500 = df_sp500.rename(columns={'Unnamed: 0': 'Date', 'Unnamed: 1': 'SP500 Performance'});
print(df_sp500.head());
# Out:
#          Date  SP500 Performance
# 0  1998-01-31               0.54
# 1  1998-02-28               4.80
# 2  1998-03-31               5.16
# 3  1998-04-30               0.32
# 4  1998-05-31              -2.69

# %% [markdown]
# Set date as index.

# %%
df_sp500 = df_sp500.set_index('Date');
print(df_sp500.head());
# Out:
#             SP500 Performance
# Date
# 1998-01-31               0.54
# 1998-02-28               4.80
# 1998-03-31               5.16
# 1998-04-30               0.32
# 1998-05-31              -2.69

# %% [markdown]
# Ensure the index is in datetime format.

# %%
df_sp500.index = pd.to_datetime(df_sp500.index);
print(df_sp500);
# Out:
#             SP500 Performance
# Date
# 1998-01-31               0.54
# 1998-02-28               4.80
# 1998-03-31               5.16
# 1998-04-30               0.32
# 1998-05-31              -2.69
# ...                       ...
# 2024-05-31               4.94
# 2024-06-28               3.08
# 2024-07-31               0.94
# 2024-08-30               2.00
# 2024-09-30               2.46
#
# [321 rows x 1 columns]

# %% [markdown]
# Trim SP500 dataset so it matches the date ranges of the screens being analyzed.

# %%
df_sp500 = df_sp500.loc['1999-01-01':];
print(df_sp500);
# Out:
#             SP500 Performance
# Date
# 1999-01-31               4.20
# 1999-02-28              -2.72
# 1999-03-31               4.06
# 1999-04-30               3.20
# 1999-05-31              -3.90
# ...                       ...
# 2024-05-31               4.94
# 2024-06-28               3.08
# 2024-07-31               0.94
# 2024-08-30               2.00
# 2024-09-30               2.46
#
# [309 rows x 1 columns]

# %% [markdown]
# Combine into single data frame named 'df_combined'.

# %%
df_sp500.index = pd.to_datetime(df_sp500.index);
df_screens.index = pd.to_datetime(df_screens.index);
df_combined = pd.concat([df_screens, df_sp500], axis=1);
print(df_combined);
# Out:
#             ADR Screen  Buffett: Hagstrom Screen  Buffettology: EPS Growth  \
# Date
# 1999-01-31        3.87                      7.96                      2.99
# 1999-02-28       -4.04                     -5.72                     -9.88
# 1999-03-31       -4.85                      5.56                     -2.61
# 1999-04-30       12.30                      5.44                      9.23
# 1999-05-31       -6.25                     -0.20                      1.10
# ...                ...                       ...                       ...
# 2024-05-31        5.38                      1.76                      6.13
# 2024-06-28       -6.42                     -2.42                     -0.39
# 2024-07-31        3.62                     10.54                      8.14
# 2024-08-30        3.81                     -0.75                     -1.79
# 2024-09-30        1.84                      2.78                      1.48
#
#             Buffettology: Sustainable Growth Screen  Cash Rich Firms Screen  \
# Date
# 1999-01-31                                     4.81                    3.21
# 1999-02-28                                   -10.49                   -9.79
# 1999-03-31                                    -2.31                   -0.33
# 1999-04-30                                     9.12                    6.20
# 1999-05-31                                     2.63                    9.19
# ...                                             ...                     ...
# 2024-05-31                                     4.67                    1.77
# 2024-06-28                                    -1.57                   -2.35
# 2024-07-31                                     7.96                    9.42
# 2024-08-30                                    -1.65                   -3.60
# 2024-09-30                                     2.72                    2.36
#
#             Dividend (High Relative Yield) Screen  Dogs of the Dow Screen  \
# Date
# 1999-01-31                                   0.03                   -1.29
# 1999-02-28                                  -3.26                   -1.07
# 1999-03-31                                  -1.24                    4.16
# 1999-04-30                                   9.10                   16.12
# 1999-05-31                                   1.57                   -3.26
# ...                                           ...                     ...
# 2024-05-31                                   2.59                    1.57
# 2024-06-28                                   2.13                   -2.60
# 2024-07-31                                  15.48                    5.88
# 2024-08-30                                  -0.51                   -0.01
# 2024-09-30                                  -0.85                    0.98
#
#             Dogs of the Dow: Low Priced 5 Screen  Dreman Screen  \
# Date
# 1999-01-31                                  0.16          -7.05
# 1999-02-28                                 -2.19           1.16
# 1999-03-31                                  1.71          -1.07
# 1999-04-30                                 18.74          12.63
# 1999-05-31                                  0.27           8.63
# ...                                          ...            ...
# 2024-05-31                                 -0.43           2.05
# 2024-06-28                                 -5.97          -3.45
# 2024-07-31                                  1.81           6.73
# 2024-08-30                                 -2.24           1.82
# 2024-09-30                                  2.23           2.67
#
#             Dreman With Est Revisions Screen  ...  \
# Date                                          ...
# 1999-01-31                             -2.22  ...
# 1999-02-28                             -3.68  ...
# 1999-03-31                              2.11  ...
# 1999-04-30                              4.89  ...
# 1999-05-31                              0.45  ...
# ...                                      ...  ...
# 2024-05-31                              3.13  ...
# 2024-06-28                             -5.38  ...
# 2024-07-31                              6.13  ...
# 2024-08-30                             -0.71  ...
# 2024-09-30                              0.91  ...
#
#             Stock Market Winners Screen  T. Rowe Price Screen  \
# Date
# 1999-01-31                        -3.42                  0.25
# 1999-02-28                        10.31                 -4.42
# 1999-03-31                        -4.78                 -8.30
# 1999-04-30                        -0.62                  9.34
# 1999-05-31                         6.62                  1.89
# ...                                 ...                   ...
# 2024-05-31                        12.10                 -1.65
# 2024-06-28                        -4.16                 -7.25
# 2024-07-31                        10.58                 -8.23
# 2024-08-30                         2.47                 -5.07
# 2024-09-30                         0.63                  0.00
#
#             Templeton Screen  Value on the Move--PEG With Est Growth Screen  \
# Date
# 1999-01-31              0.08                                           3.19
# 1999-02-28             -3.92                                          -7.22
# 1999-03-31              0.64                                          -4.56
# 1999-04-30              7.04                                           9.10
# 1999-05-31              6.86                                           0.55
# ...                      ...                                            ...
# 2024-05-31              5.60                                           8.67
# 2024-06-28             -1.44                                          -0.81
# 2024-07-31              6.19                                          -0.72
# 2024-08-30              2.25                                           2.02
# 2024-09-30              1.16                                           1.99
#
#             Value on the Move--PEG With Hist Growth Screen  \
# Date
# 1999-01-31                                            0.57
# 1999-02-28                                           -6.25
# 1999-03-31                                           -3.26
# 1999-04-30                                            6.66
# 1999-05-31                                            0.49
# ...                                                    ...
# 2024-05-31                                            4.89
# 2024-06-28                                           -0.82
# 2024-07-31                                            8.00
# 2024-08-30                                            1.26
# 2024-09-30                                            4.75
#
#             Wanger (Revised) Screen  Weiss Blue Chip Div Yield Screen  \
# Date
# 1999-01-31                     1.50                             -6.56
# 1999-02-28                    -8.00                             -5.25
# 1999-03-31                    -2.38                             -1.20
# 1999-04-30                    10.75                             12.52
# 1999-05-31                     4.88                              3.54
# ...                             ...                               ...
# 2024-05-31                    -3.24                              1.83
# 2024-06-28                     0.00                              4.46
# 2024-07-31                     8.80                             14.08
# 2024-08-30                     0.00                             -5.38
# 2024-09-30                    35.14                              4.72
#
#             Zweig Screen  Average Performance  SP500 Performance
# Date
# 1999-01-31          9.43             3.121273               4.20
# 1999-02-28         -1.35            -4.845636              -2.72
# 1999-03-31         -9.19             0.074727               4.06
# 1999-04-30         13.15             7.922909               3.20
# 1999-05-31         -1.65             2.706182              -3.90
# ...                  ...                  ...                ...
# 2024-05-31          5.72             4.738000               4.94
# 2024-06-28          1.94            -2.554182               3.08
# 2024-07-31        -15.74             5.810000               0.94
# 2024-08-30          0.72            -0.252182               2.00
# 2024-09-30         -1.09             2.732727               2.46
#
# [309 rows x 57 columns]

# %% [markdown]
# We can now see the cleaned and combined data set with both benchmarks included!

# %%
df_combined.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 309 entries, 1999-01-31 to 2024-09-30
# Data columns (total 57 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   ADR Screen                                       309 non-null    float64
#  1   Buffett: Hagstrom Screen                         309 non-null    float64
#  2   Buffettology: EPS Growth                         309 non-null    float64
#  3   Buffettology: Sustainable Growth Screen          309 non-null    float64
#  4   Cash Rich Firms Screen                           309 non-null    float64
#  5   Dividend (High Relative Yield) Screen            309 non-null    float64
#  6   Dogs of the Dow Screen                           309 non-null    float64
#  7   Dogs of the Dow: Low Priced 5 Screen             309 non-null    float64
#  8   Dreman Screen                                    309 non-null    float64
#  9   Dreman With Est Revisions Screen                 309 non-null    float64
#  10  Driehaus Revised Screen                          309 non-null    float64
#  11  Driehaus Screen                                  309 non-null    float64
#  12  Dual Cash Flow Screen                            309 non-null    float64
#  13  Est Rev: Down 5% Screen                          309 non-null    float64
#  14  Est Rev: Lowest 30 Down                          309 non-null    float64
#  15  Est Rev: Top 30 Up                               309 non-null    float64
#  16  Est Rev: Up 5% Screen                            309 non-null    float64
#  17  Fisher (Philip) Screen                           309 non-null    float64
#  18  Fundamental Rule of Thumb Screen                 309 non-null    float64
#  19  Graham--Defensive Investor (Non-Utility) Screen  309 non-null    float64
#  20  Graham--Defensive Investor (Utility) Screen      309 non-null    float64
#  21  Graham--Enterprising Investor Revised            309 non-null    float64
#  22  Insider Net Purchases Screen                     309 non-null    float64
#  23  Kirkpatrick Bargain Screen                       309 non-null    float64
#  24  Kirkpatrick Growth Screen                        309 non-null    float64
#  25  Kirkpatrick Value Screen                         309 non-null    float64
#  26  Lakonishok Screen                                309 non-null    float64
#  27  Lynch Screen                                     309 non-null    float64
#  28  Magic Formula Screen                             309 non-null    float64
#  29  Muhlenkamp Screen                                309 non-null    float64
#  30  Neff Screen                                      309 non-null    float64
#  31  O'Neil's CAN SLIM No Float Screen                309 non-null    float64
#  32  O'Neil's CAN SLIM Revised 3rd Edition Screen     309 non-null    float64
#  33  O'Neil's CAN SLIM Screen                         309 non-null    float64
#  34  O'Shaughnessy: All Cap Screen                    309 non-null    float64
#  35  O'Shaughnessy: Growth Market Leaders Screen      309 non-null    float64
#  36  O'Shaughnessy: Growth Screen II                  309 non-null    float64
#  37  O'Shaughnessy: Small Cap Growth & Value Screen   309 non-null    float64
#  38  O'Shaughnessy: Tiny Titans Screen                309 non-null    float64
#  39  O'Shaughnessy: Value Screen                      309 non-null    float64
#  40  P/E Relative Screen                              309 non-null    float64
#  41  Piotroski: High F-Score Screen                   309 non-null    float64
#  42  Price-to-Free-Cash-Flow Screen                   309 non-null    float64
#  43  Price-to-Sales Screen                            309 non-null    float64
#  44  Return on Equity Screen                          309 non-null    float64
#  45  Rule #1 Investing Screen                         309 non-null    float64
#  46  Schloss Screen                                   309 non-null    float64
#  47  Stock Market Winners Screen                      309 non-null    float64
#  48  T. Rowe Price Screen                             309 non-null    float64
#  49  Templeton Screen                                 309 non-null    float64
#  50  Value on the Move--PEG With Est Growth Screen    309 non-null    float64
#  51  Value on the Move--PEG With Hist Growth Screen   309 non-null    float64
#  52  Wanger (Revised) Screen                          309 non-null    float64
#  53  Weiss Blue Chip Div Yield Screen                 309 non-null    float64
#  54  Zweig Screen                                     309 non-null    float64
#  55  Average Performance                              309 non-null    float64
#  56  SP500 Performance                                309 non-null    float64
# dtypes: float64(57)
# memory usage: 140.0 KB

# %% [markdown]
# I will now analyze each screen to inform a few questions:
#
# Macro Question: As an investor, I want to determine if using well-known stock screening strategies offers a significant advantage in the current market compared to simply investing in a low-cost S&P 500 ETF. If active investing with stock screens has historically provided better returns, how can I identify which screens to use and when to invest in them?
#
# 1. On average do screens provide better returns than the SP500?
# 2. What are the best performing screens:
#   1. What are the top performing screens by average/median monthly return?
#   2. What are the top performing screens by most months showing outperformance of benchmarks?
# 3. Momentum:
#   1. Is there a momentum factor associated with screen performance?
#   2. Is there a momentum factor associated with SP500 performance?
#   3. If so, does it increase the longer a streak is intact?
#   4. Are higher performing screens more or less likely to have a momentum factor?

# %% [markdown]
# Best Performing screens by mean and median monthly return.

# %%
avg_returns = df_combined.mean(axis=0);
median_returns = df_combined.median(axis=0);
print(avg_returns.sort_values(ascending=False));
print(median_returns.sort_values(ascending=False));
# Out:
# O'Shaughnessy: Tiny Titans Screen                  2.116537
# Est Rev: Up 5% Screen                              1.867638
# Est Rev: Top 30 Up                                 1.841553
# Driehaus Revised Screen                            1.836699
# O'Neil's CAN SLIM Screen                           1.727120
# O'Shaughnessy: Small Cap Growth & Value Screen     1.674207
# Price-to-Free-Cash-Flow Screen                     1.613107
# Piotroski: High F-Score Screen                     1.556570
# O'Shaughnessy: Growth Screen II                    1.529061
# O'Neil's CAN SLIM Revised 3rd Edition Screen       1.521327
# Kirkpatrick Growth Screen                          1.424175
# Stock Market Winners Screen                        1.421586
# Driehaus Screen                                    1.405081
# Dreman With Est Revisions Screen                   1.362848
# Neff Screen                                        1.353333
# Graham--Enterprising Investor Revised              1.352913
# Value on the Move--PEG With Est Growth Screen      1.329903
# Kirkpatrick Value Screen                           1.285016
# O'Neil's CAN SLIM No Float Screen                  1.228479
# Buffettology: Sustainable Growth Screen            1.216634
# P/E Relative Screen                                1.192168
# Lakonishok Screen                                  1.183948
# Graham--Defensive Investor (Non-Utility) Screen    1.167929
# Value on the Move--PEG With Hist Growth Screen     1.153042
# Buffett: Hagstrom Screen                           1.148544
# Price-to-Sales Screen                              1.114078
# Return on Equity Screen                            1.100550
# Buffettology: EPS Growth                           1.096149
# Average Performance                                1.095655
# Dual Cash Flow Screen                              1.090097
# Rule #1 Investing Screen                           1.040032
# Fundamental Rule of Thumb Screen                   1.034272
# Wanger (Revised) Screen                            1.018026
# O'Shaughnessy: All Cap Screen                      1.013495
# Zweig Screen                                       1.002427
# Templeton Screen                                   0.958511
# Weiss Blue Chip Div Yield Screen                   0.954304
# Fisher (Philip) Screen                             0.903560
# Lynch Screen                                       0.886181
# Magic Formula Screen                               0.857896
# Dividend (High Relative Yield) Screen              0.820583
# Cash Rich Firms Screen                             0.788447
# Dreman Screen                                      0.779968
# O'Shaughnessy: Growth Market Leaders Screen        0.776149
# T. Rowe Price Screen                               0.755307
# Kirkpatrick Bargain Screen                         0.712104
# Schloss Screen                                     0.698026
# ADR Screen                                         0.695243
# Muhlenkamp Screen                                  0.648673
# Graham--Defensive Investor (Utility) Screen        0.602524
# O'Shaughnessy: Value Screen                        0.583819
# Est Rev: Lowest 30 Down                            0.567282
# SP500 Performance                                  0.459871
# Est Rev: Down 5% Screen                            0.447152
# Dogs of the Dow Screen                             0.394110
# Dogs of the Dow: Low Priced 5 Screen               0.290129
# Insider Net Purchases Screen                       0.122524
# dtype: float64
# O'Shaughnessy: Growth Screen II                    2.370000
# O'Shaughnessy: Tiny Titans Screen                  2.220000
# Est Rev: Up 5% Screen                              2.160000
# Dreman With Est Revisions Screen                   2.000000
# Est Rev: Top 30 Up                                 1.880000
# O'Shaughnessy: Small Cap Growth & Value Screen     1.680000
# Lakonishok Screen                                  1.640000
# Kirkpatrick Growth Screen                          1.560000
# Value on the Move--PEG With Est Growth Screen      1.550000
# Neff Screen                                        1.530000
# Driehaus Revised Screen                            1.480000
# Average Performance                                1.451636
# Price-to-Sales Screen                              1.450000
# Graham--Enterprising Investor Revised              1.440000
# Buffett: Hagstrom Screen                           1.420000
# Value on the Move--PEG With Hist Growth Screen     1.380000
# O'Neil's CAN SLIM No Float Screen                  1.350000
# Return on Equity Screen                            1.340000
# Piotroski: High F-Score Screen                     1.260000
# Buffettology: Sustainable Growth Screen            1.240000
# P/E Relative Screen                                1.220000
# ADR Screen                                         1.210000
# Buffettology: EPS Growth                           1.200000
# Price-to-Free-Cash-Flow Screen                     1.190000
# Dual Cash Flow Screen                              1.180000
# Dreman Screen                                      1.170000
# O'Shaughnessy: Growth Market Leaders Screen        1.170000
# Stock Market Winners Screen                        1.140000
# Graham--Defensive Investor (Non-Utility) Screen    1.120000
# Wanger (Revised) Screen                            1.080000
# Driehaus Screen                                    1.050000
# Dividend (High Relative Yield) Screen              1.050000
# Kirkpatrick Bargain Screen                         1.000000
# Lynch Screen                                       1.000000
# O'Shaughnessy: All Cap Screen                      0.950000
# Cash Rich Firms Screen                             0.920000
# Magic Formula Screen                               0.910000
# Templeton Screen                                   0.900000
# Zweig Screen                                       0.900000
# Muhlenkamp Screen                                  0.850000
# Weiss Blue Chip Div Yield Screen                   0.850000
# O'Shaughnessy: Value Screen                        0.810000
# Graham--Defensive Investor (Utility) Screen        0.800000
# SP500 Performance                                  0.780000
# Est Rev: Down 5% Screen                            0.750000
# Dogs of the Dow Screen                             0.720000
# Insider Net Purchases Screen                       0.670000
# Fundamental Rule of Thumb Screen                   0.670000
# Dogs of the Dow: Low Priced 5 Screen               0.660000
# O'Neil's CAN SLIM Screen                           0.570000
# Est Rev: Lowest 30 Down                            0.510000
# O'Neil's CAN SLIM Revised 3rd Edition Screen       0.170000
# T. Rowe Price Screen                               0.000000
# Schloss Screen                                     0.000000
# Rule #1 Investing Screen                           0.000000
# Kirkpatrick Value Screen                           0.000000
# Fisher (Philip) Screen                             0.000000
# dtype: float64

# %% [markdown]
# Now we can plot this data into a bar chart to better visualize screener performance vs. benchmarks, especially the SP500 benchmark.

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.transform import factor_cmap
from bokeh.palettes import Spectral6

output_notebook()

sorted_avg_returns = avg_returns.sort_values(ascending=False);

screens = sorted_avg_returns.index.tolist()
returns = sorted_avg_returns.values

colors = ['#ff0000' if screen in ['SP500 Performance', 'Average Performance'] else '#1f77b4' for screen in screens]

source = ColumnDataSource(data=dict(
    screens=screens,
    returns=returns,
    colors=colors
))

p = figure(x_range=screens, height=600, width=900, title="Mean Return of Each Screen and Benchmark",
           toolbar_location=None, tools="", x_axis_label='Screens/Benchmarks', y_axis_label='Mean Monthly Return (%)')

p.vbar(x='screens', top='returns', width=0.8, source=source,
       fill_color='colors')

hover = HoverTool()
hover.tooltips = [("Screen", "@screens"), ("Mean Return (%)", "@returns{0.00}")]
p.add_tools(hover)

p.xaxis.major_label_orientation = "vertical"

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p);
# Out:
#   <div id="e5f02e0f-8e00-4fe4-8cca-0cc8fcd35543" data-root-id="p2134" style="display: contents;"></div>

# %%
output_notebook()

sorted_median_returns = median_returns.sort_values(ascending=False);

screens = sorted_median_returns.index.tolist()
returns = sorted_median_returns.values

colors = ['#ff0000' if screen in ['SP500 Performance', 'Average Performance'] else '#1f77b4' for screen in screens]

source = ColumnDataSource(data=dict(
    screens=screens,
    returns=returns,
    colors=colors
))

p = figure(x_range=screens, height=600, width=900, title="Median Return of Each Screen and Benchmark",
           toolbar_location=None, tools="", x_axis_label='Screens/Benchmarks', y_axis_label='Median Monthly Return (%)')

p.vbar(x='screens', top='returns', width=0.8, source=source,
       fill_color='colors')

hover = HoverTool()
hover.tooltips = [("Screen", "@screens"), ("Median Return (%)", "@returns{0.00}")]
p.add_tools(hover)

p.xaxis.major_label_orientation = "vertical"

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p);
# Out:
#   <div id="c63578f2-46d0-42e4-90e7-3ac8a2125010" data-root-id="p2208" style="display: contents;"></div>

# %% [markdown]
# After comparing sorted mean returns and median returns we can see a few things:
#
# 1. On both a mean and meadian comparison we see screens definitively outperform the SP500.
#
# 2. Less screens outperform the SP500 average on a median basis.  This could suggest the presence of outliers as well as a higher standard deviation (volatility) among screens on average.
#
# What does this mean?
# Ideally, as an investor I would want screens that not only outperform in aggregate but also outperform on a more regular basis.  Therefore I would also like to see how often a screen outperforms the SP500 benchmark.

# %%
outperformance_df = df_combined.iloc[:, :-1].gt(df_combined['SP500 Performance'], axis=0)

outperformance_percentage = (outperformance_df.mean() * 100).sort_values(ascending=False)

summary_table = pd.DataFrame({
    'Outperform Percentage (%)': outperformance_percentage
})

print(summary_table.head());
# Out:
#                                    Outperform Percentage (%)
# O'Shaughnessy: Tiny Titans Screen                  61.812298
# Est Rev: Top 30 Up                                 61.488673
# Buffett: Hagstrom Screen                           59.870550
# Price-to-Sales Screen                              59.546926
# Est Rev: Up 5% Screen                              59.546926

# %%
output_notebook()

outperform_sorted = summary_table['Outperform Percentage (%)'].sort_values(ascending=False)

screens = outperform_sorted.index.tolist()
outperform_percentage = outperform_sorted.values - 50
total_outperform_percentage = outperform_sorted.values

colors = ['#ff0000' if screen in ['SP500 Performance', 'Average Performance'] else '#1f77b4' for screen in screens]

source = ColumnDataSource(data=dict(
    screens=screens,
    outperform_percentage=outperform_percentage,
    colors=colors,
    total_outperform_percentage=total_outperform_percentage
))

p = figure(x_range=screens, height=600, width=900, title="Outperformance Percentage of Each Screen Relative to SP500",
           toolbar_location=None, tools="", x_axis_label='Screens', y_axis_label='Outperformance Percentage (%)')

bars = p.vbar(x='screens', top='outperform_percentage', width=0.8, source=source,
       fill_color='colors')

hover = HoverTool()
hover.tooltips = [("Screen", "@screens"), ("Outperformance of SP500 (%)", "@total_outperform_percentage{0.00}")]
p.add_tools(hover)

p.xaxis.major_label_orientation = "vertical"

p.xgrid.grid_line_color = None
p.y_range.start = -10
p.y_range.end = 20

show(p)
# Out:
#   <div id="f6beaa05-0ba1-403e-92ff-cd9d9f616a47" data-root-id="p2634" style="display: contents;"></div>

# %% [markdown]
# These results show that not only do the screens outperform the market on average over time, but they also demonstrate superior performance on a median basis. Additionally, the data indicates that, on average, most screens outperform the market on a monthly basis, with a success rate of 58.25%.
#
# Given this revelation I would like to create a bucket of 'Outperforming Screens' that will meet the following criteria:
# 1. Outperform the SP500 on a cumulative average basis.
# 2. Outperform the SP500 on a cumulative median basis.
# 3. Outperform the market on a monthly basis more than 50% of the time.
#
# Stocks not meeting this criteria will be grouped into a second bucket named 'Underperforming Screens'
#
# *I also ensured that neither 'SP500 Performance' or 'Average Performance' would not be included in these buckets.

# %%
summary_returns = pd.concat([avg_returns, median_returns, outperformance_percentage], axis=1).fillna(0);
summary_returns.columns = ['Mean Monthly Return %', 'Median Monthly Return %', 'Outperform SP500 Monthly Basis Success Rate %'];

SP500_mean_monthly_return = avg_returns['SP500 Performance'];
SP500_median_monthly_return = median_returns['SP500 Performance'];

outperforming_screens = summary_returns[
    (summary_returns['Mean Monthly Return %'] > SP500_mean_monthly_return) &
    (summary_returns['Median Monthly Return %'] > SP500_median_monthly_return) &
    (summary_returns['Outperform SP500 Monthly Basis Success Rate %'] > 50)
].drop('Average Performance');

underperforming_screens = summary_returns[
    (summary_returns['Mean Monthly Return %'] <= SP500_mean_monthly_return) |
    (summary_returns['Median Monthly Return %'] <= SP500_median_monthly_return) |
    (summary_returns['Outperform SP500 Monthly Basis Success Rate %'] <= 50)
].drop('SP500 Performance');

print(outperforming_screens.describe());
print(underperforming_screens.describe());
# Out:
#        Mean Monthly Return %  Median Monthly Return %  \
# count              39.000000                39.000000
# mean                1.198263                 1.326923
# std                 0.355147                 0.387815
# min                 0.648673                 0.850000
# 25%                 0.956408                 1.050000
# 50%                 1.153042                 1.210000
# 75%                 1.383964                 1.505000
# max                 2.116537                 2.370000
#
#        Outperform SP500 Monthly Basis Success Rate %
# count                                      39.000000
# mean                                       55.572152
# std                                         3.448138
# min                                        50.161812
# 25%                                        52.427184
# 50%                                        56.310680
# 75%                                        58.252427
# max                                        61.812298
#        Mean Monthly Return %  Median Monthly Return %  \
# count              16.000000                16.000000
# mean                0.845548                 0.474375
# std                 0.478749                 0.392547
# min                 0.122524                 0.000000
# 25%                 0.537249                 0.000000
# 50%                 0.726667                 0.615000
# 75%                 1.101278                 0.727500
# max                 1.727120                 1.260000
#
#        Outperform SP500 Monthly Basis Success Rate %
# count                                      16.000000
# mean                                       49.635922
# std                                         2.345255
# min                                        45.631068
# 25%                                        48.786408
# 50%                                        49.190939
# 75%                                        50.000000
# max                                        56.957929
